# %% [markdown]
# ### Escuela Politécnica Nacional ###
#
# **Nombre:** Marco Marcillo
#
# **Tema:** [Actividad extracurricular 04] curso de git y Github
#
# **Repositorio GIT:** https://github.com/Alejandro0122/MN_PERSONAL

# %% [markdown]
# ### Curso online de git y Github###
# ![image.png](attachment:image.png)

# %% [markdown]
# Comprobación de conceptos GIT
#
# commit, fork, pull request, submodule, stash, branch, remote, fetch, push, origin, upstream.

# %% [markdown]
# ### commit ###
# ![image.png](attachment:image.png)

# %% [markdown]
# ### fork ###
# ![image.png](attachment:image.png)

# %% [markdown]
# ### pull request ###
# ![image.png](attachment:image.png)

# %% [markdown]
# ### submodule ###
# ![image.png](attachment:image.png)

# %% [markdown]
# ### fetch ###
# ![image.png](attachment:image.png)

# %% [markdown]
# ### push ###
# ![image.png](attachment:image.png)

# %% [markdown]
# ### stash ###
# ![image.png](attachment:image.png)

# %% [markdown]
# ### branch ###
# ![image.png](attachment:image.png)

# %% [markdown]
# ### remote ###
# ![image.png](attachment:image.png)

# %% [markdown]
# ### origin ###
# ![image.png](attachment:image.png)
